# %%
## This notebook will analyze the queries collected from the workshop on 03/24/25.

import pandas as pd

# %%
df = pd.read_csv('/Users/edwinhuang/Desktop/032425hackathon_copilot_conversations.csv')

# %%
df
# Out:
#       id  conversation_id                                        user_prompt  \
# 0    519     2.580000e+17      how long should hierarchical clustering take?
# 1    532     2.580000e+17  what files should be output from running Hiera...
# 2    536     2.580000e+17                 im getting error, missing argument
# 3    542     2.580000e+17            how should output basename be formatted
# 4    678     5.710000e+17  How can genepattern handle outliers in replica...
# ..   ...              ...                                                ...
# 178  662     8.820000e+18  tell me about all the modules you have in Gene...
# 179  666     8.820000e+18  I have a featurecounts file. I'd like to perfo...
# 180  667     8.820000e+18  how do you convert a csv or xlsx file into gct...
# 181  677     8.820000e+18  The output from SelectFileMatrix is a .select ...
# 182  682     8.820000e+18  Can I use GenePattern to analyze ATAC-seq or C...
#
# ...
